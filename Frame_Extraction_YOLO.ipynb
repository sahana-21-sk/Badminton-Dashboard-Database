# %%
import os

os.makedirs("extracted_frames", exist_ok=True)

print("Folder created!")
# Out:
# Folder created!

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-39f09824-57b6-436b-9d99-bd00b12fbb9f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-39f09824-57b6-436b-9d99-bd00b12fbb9f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2
import os

# %%
video_path = list(uploaded.keys())[0]

cap = cv2.VideoCapture(video_path)

print("Video loaded successfully!")
# Out:
# Video loaded successfully!

# %%
frame_count = 0
saved_count = 0

while True:
    ret, frame = cap.read()

    if not ret:
        breakw

    # Save every 5th frame
    if frame_count % 5 == 0:
        frame_name = f"extracted_frames/frame_{saved_count}.jpg"
        cv2.imwrite(frame_name, frame)
        saved_count += 1

    frame_count += 1

cap.release()

print(f"{saved_count} frames extracted!")
# Out:
# 297 frames extracted!

# %%
import os

len(os.listdir("extracted_frames"))
# Out:
# 297

# %%
import matplotlib.pyplot as plt

image = cv2.imread("extracted_frames/frame_0.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image)
plt.axis("off")
plt.show()

# %%
# !zip -r extracted_frames.zip extracted_frames
# Out:
#   adding: extracted_frames/ (stored 0%)
#   adding: extracted_frames/frame_155.jpg (deflated 0%)
#   adding: extracted_frames/frame_101.jpg (deflated 0%)
#   adding: extracted_frames/frame_247.jpg (deflated 0%)
#   adding: extracted_frames/frame_151.jpg (deflated 0%)
#   adding: extracted_frames/frame_115.jpg (deflated 0%)
#   adding: extracted_frames/frame_190.jpg (deflated 1%)
#   adding: extracted_frames/frame_141.jpg (deflated 0%)
#   adding: extracted_frames/frame_230.jpg (deflated 0%)
#   adding: extracted_frames/frame_72.jpg (deflated 0%)
#   adding: extracted_frames/frame_111.jpg (deflated 1%)
#   adding: extracted_frames/frame_150.jpg (deflated 0%)
#   adding: extracted_frames/frame_112.jpg (deflated 0%)
#   adding: extracted_frames/frame_172.jpg (deflated 1%)
#   adding: extracted_frames/frame_22.jpg (deflated 0%)
#   adding: extracted_frames/frame_126.jpg (deflated 1%)
#   adding: extracted_frames/frame_208.jpg (deflated 1%)
# ...

# %%
from google.colab import files

files.download("extracted_frames.zip")

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-34042aa7-fd99-4954-b4dc-9e94050a3343" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-34042aa7-fd99-4954-b4dc-9e94050a3343">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
video_path = list(uploaded.keys())[0]

cap = cv2.VideoCapture(video_path)

print("Video loaded successfully!")
# Out:
# Video loaded successfully!

# %%
frame_count = 0
saved_count = 0

while True:
    ret, frame = cap.read()

    if not ret:
        break

    # Save every 5th frame
    if frame_count % 2 == 0:
        frame_name = f"extracted_frames/frame_{saved_count}.jpg"
        cv2.imwrite(frame_name, frame)
        saved_count += 1

    frame_count += 1

cap.release()

print(f"{saved_count} frames extracted!")
# Out:
# 417 frames extracted!

# %%
import matplotlib.pyplot as plt

image = cv2.imread("extracted_frames/frame_0.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image)
plt.axis("off")
plt.show()

# %%
# !zip -r extracted_frames.zip extracted_frames
# Out:
# updating: extracted_frames/ (stored 0%)
# updating: extracted_frames/frame_155.jpg (deflated 3%)
# updating: extracted_frames/frame_101.jpg (deflated 2%)
# updating: extracted_frames/frame_247.jpg (deflated 2%)
# updating: extracted_frames/frame_151.jpg (deflated 2%)
# updating: extracted_frames/frame_115.jpg (deflated 2%)
# updating: extracted_frames/frame_190.jpg (deflated 2%)
# updating: extracted_frames/frame_141.jpg (deflated 2%)
# updating: extracted_frames/frame_230.jpg (deflated 3%)
# updating: extracted_frames/frame_72.jpg (deflated 2%)
# updating: extracted_frames/frame_111.jpg (deflated 2%)
# updating: extracted_frames/frame_150.jpg (deflated 2%)
# updating: extracted_frames/frame_112.jpg (deflated 2%)
# updating: extracted_frames/frame_172.jpg (deflated 2%)
# updating: extracted_frames/frame_22.jpg (deflated 3%)
# updating: extracted_frames/frame_126.jpg (deflated 2%)
# updating: extracted_frames/frame_208.jpg (deflated 3%)
# ...

# %%
from google.colab import files

files.download("extracted_frames.zip")

# %%
import os

os.makedirs("extracted_frames", exist_ok=True)

print("Folder created!")
# Out:
# Folder created!

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-4110f6c5-e273-4fbe-8b37-2333af17ab9e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4110f6c5-e273-4fbe-8b37-2333af17ab9e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2
import os

# %%
video_path = list(uploaded.keys())[0]

cap = cv2.VideoCapture(video_path)

print("Video loaded successfully!")
# Out:
# Video loaded successfully!

# %%
frame_count = 0
saved_count = 0

while True:
    ret, frame = cap.read()

    if not ret:
        break

    # Save every 5th frame
    if frame_count % 4== 0:
        frame_name = f"extracted_frames/frame_{saved_count}.jpg"
        cv2.imwrite(frame_name, frame)
        saved_count += 1

    frame_count += 1

cap.release()

print(f"{saved_count} frames extracted!")
# Out:
# 415 frames extracted!

# %%
frame_count = 0
saved_count = 0

while True:
    ret, frame = cap.read()

    if not ret:
        break

    # Save every 5th frame
    if frame_count % 5 == 0:
        frame_name = f"extracted_frames/frame_{saved_count}.jpg"
        cv2.imwrite(frame_name, frame)
        saved_count += 1

    frame_count += 1

cap.release()

print(f"{saved_count} frames extracted!")
# Out:
# 0 frames extracted!

# %%
import matplotlib.pyplot as plt

image = cv2.imread("extracted_frames/frame_0.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image)
plt.axis("off")
plt.show()

# %%
# !zip -r extracted_frames.zip extracted_frames
# Out:
#   adding: extracted_frames/ (stored 0%)
#   adding: extracted_frames/frame_155.jpg (deflated 1%)
#   adding: extracted_frames/frame_406.jpg (deflated 5%)
#   adding: extracted_frames/frame_451.jpg (deflated 5%)
#   adding: extracted_frames/frame_748.jpg (deflated 5%)
#   adding: extracted_frames/frame_650.jpg (deflated 6%)
#   adding: extracted_frames/frame_101.jpg (deflated 4%)
#   adding: extracted_frames/frame_652.jpg (deflated 5%)
#   adding: extracted_frames/frame_247.jpg (deflated 1%)
#   adding: extracted_frames/frame_689.jpg (deflated 5%)
#   adding: extracted_frames/frame_151.jpg (deflated 1%)
#   adding: extracted_frames/frame_314.jpg (deflated 6%)
#   adding: extracted_frames/frame_365.jpg (deflated 5%)
#   adding: extracted_frames/frame_463.jpg (deflated 5%)
#   adding: extracted_frames/frame_435.jpg (deflated 5%)
#   adding: extracted_frames/frame_115.jpg (deflated 3%)
#   adding: extracted_frames/frame_378.jpg (deflated 5%)
# ...

# %%
from google.colab import files

files.download("extracted_frames.zip")

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-b7778154-7e85-4d39-b425-20edb3312426" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b7778154-7e85-4d39-b425-20edb3312426">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2
import os

# %%
video_path = list(uploaded.keys())[0]

cap = cv2.VideoCapture(video_path)

print("Video loaded successfully!")
# Out:
# Video loaded successfully!

# %%
frame_count = 0
saved_count = 0

while True:
    ret, frame = cap.read()

    if not ret:
        break

    # Save every 5th frame
    if frame_count % 2 == 0:
        frame_name = f"extracted_frames/frame_{saved_count}.jpg"
        cv2.imwrite(frame_name, frame)
        saved_count += 1

    frame_count += 1

cap.release()

print(f"{saved_count} frames extracted!")
# Out:
# 174 frames extracted!

# %%
import os

len(os.listdir("extracted_frames"))
# Out:
# 830

# %%
import matplotlib.pyplot as plt

image = cv2.imread("extracted_frames/frame_0.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image)
plt.axis("off")
plt.show()

# %%
# !zip -r extracted_frames.zip extracted_frames
# Out:
# updating: extracted_frames/ (stored 0%)
# updating: extracted_frames/frame_155.jpg (deflated 0%)
# updating: extracted_frames/frame_406.jpg (deflated 5%)
# updating: extracted_frames/frame_451.jpg (deflated 5%)
# updating: extracted_frames/frame_748.jpg (deflated 5%)
# updating: extracted_frames/frame_650.jpg (deflated 6%)
# updating: extracted_frames/frame_101.jpg (deflated 0%)
# updating: extracted_frames/frame_652.jpg (deflated 5%)
# updating: extracted_frames/frame_247.jpg (deflated 0%)
# updating: extracted_frames/frame_689.jpg (deflated 5%)
# updating: extracted_frames/frame_151.jpg (deflated 0%)
# updating: extracted_frames/frame_314.jpg (deflated 0%)
# updating: extracted_frames/frame_365.jpg (deflated 5%)
# updating: extracted_frames/frame_463.jpg (deflated 5%)
# updating: extracted_frames/frame_435.jpg (deflated 5%)
# updating: extracted_frames/frame_115.jpg (deflated 0%)
# updating: extracted_frames/frame_378.jpg (deflated 5%)
# ...

# %%
from google.colab import files

files.download("extracted_frames.zip")

# %%
import os

os.makedirs("extracted_frames", exist_ok=True)

print("Folder created!")
# Out:
# Folder created!

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-b85cc574-35d1-4c4f-a571-05838fb4a204" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b85cc574-35d1-4c4f-a571-05838fb4a204">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2
import os

# %%
video_path = list(uploaded.keys())[0]

cap = cv2.VideoCapture(video_path)

print("Video loaded successfully!")
# Out:
# Video loaded successfully!

# %%
frame_count = 0
saved_count = 0

while True:
    ret, frame = cap.read()

    if not ret:
        break

    # Save every 5th frame
    if frame_count % 4 == 0:
        frame_name = f"extracted_frames/frame_{saved_count}.jpg"
        cv2.imwrite(frame_name, frame)
        saved_count += 1

    frame_count += 1

cap.release()

print(f"{saved_count} frames extracted!")
# Out:
# 406 frames extracted!

# %%
import matplotlib.pyplot as plt

image = cv2.imread("extracted_frames/frame_0.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image)
plt.axis("off")
plt.show()

# %%
# !zip -r extracted_frames.zip extracted_frames
# Out:
# updating: extracted_frames/ (stored 0%)
# updating: extracted_frames/frame_155.jpg (deflated 0%)
# updating: extracted_frames/frame_406.jpg (deflated 5%)
# updating: extracted_frames/frame_451.jpg (deflated 5%)
# updating: extracted_frames/frame_748.jpg (deflated 5%)
# updating: extracted_frames/frame_650.jpg (deflated 6%)
# updating: extracted_frames/frame_101.jpg (deflated 1%)
# updating: extracted_frames/frame_652.jpg (deflated 5%)
# updating: extracted_frames/frame_247.jpg (deflated 1%)
# updating: extracted_frames/frame_689.jpg (deflated 5%)
# updating: extracted_frames/frame_151.jpg (deflated 0%)
# updating: extracted_frames/frame_314.jpg (deflated 1%)
# updating: extracted_frames/frame_365.jpg (deflated 1%)
# updating: extracted_frames/frame_463.jpg (deflated 5%)
# updating: extracted_frames/frame_435.jpg (deflated 5%)
# updating: extracted_frames/frame_115.jpg (deflated 0%)
# updating: extracted_frames/frame_378.jpg (deflated 1%)
# ...

# %%
from google.colab import files

files.download("extracted_frames.zip")
